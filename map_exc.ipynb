# %% [markdown]
# # MAP
#
# ###### The following notebook is a quick excercise with pandas, folium, and matplotlib.
# ###### The expected result is a folium map showing places grouped by year.
# ###### Each year should be represented by a different color.

# %%
#importing the needed libraries

import folium
import pandas as pd
import geocoder
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
#g = geocoder.arcgis("Ischigualasto, Argentina")
#lat = g.json['lat']
#lng = g.json['lng']
#print(lat)
#print(lng)

# %%
#creating a dataframe of all the places.

places_years = (
    ("Santiago, Chile", 2017),
    ("El Quisco, Chile", 2017),
    
    ("Viña del Mar, Chile", 2018),
    
    ("San Carlos de Bariloche, Argentina", 2018), 
    ("Lago Puelo, Argentina", 2018),
    ("Lago Gutiérrez,Argentina", 2018),
    ("Villa La Angostura,Argentina", 2018),
    ("Villa Traful,Argentina", 2018),
    ("Villa Tacul, Argentina", 2018),
    ("Asociación Camping Musical Bariloche, Argentina, Argentina", 2018),
    ("San Martín de los Andes, Argentina", 2018),
    ("Lago Flakner, Argentina", 2018),
    ("Colonia Suiza, Argentina", 2018),
    ("El Bolsón, Argentina", 2018),
    
    ("Merlo, Argentina", 2019),
    ("Trapiche, Argentina", 2019),
    
    ("San Luis, Argentina", 2020),
    ("Las Grutas,Argentina", 2020),
    ("Península de Valdez, Argentina", 2020),
    ("Puerto Madryn, Argentina", 2020),
    ("Lago Futalaufquen, Argentina", 2020),
    ("Lago Menendez, Argentina", 2020),
    ("Lago Rivadavia, Argentina", 2020),
    ("El Bolsón, Argentina", 2020),
    ("San Carlos de Bariloche, Argentina", 2020),
    ("Junín de los Andes, Argentina", 2020),
    ("Lago Huechulafken,Argentina", 2020),
    ("Chos Malal,Argentina", 2020),
    ("Malargüe,Argentina", 2020),

    ("Neuquén, Argentina", 2021),
    ("Villa Pehuenia, Argentina", 2021),
    ("Lago Aluminé, Argentina", 2021),
    ("Lago Moquehue, Argentina", 2021),
    ("Lago Ñorquinco, Argentina", 2021),
    ("Lago Huechulafquen, Argentina", 2021),
    ("Lago Paimún, Argentina", 2021),
    ("Lago Tromen, Argentina", 2021),
    ("San Martín de los Andes, Argentina", 2021),
    
    ("La Rioga, Argentina", 2021),
    ("Catamarca, Argentina", 2021),
    ("Tucumán, Argentina", 2021),
    ("Salta, Argentina", 2021),
    ("Cafayate, Argentina", 2021),
    ("Tafí del Valle, Argentina", 2021),
    ("Ischigualasto, Argentina", 2021),
    ("San Juan, Argentina", 2021)
    
                )
df = pd.DataFrame(places_years)
df.columns=["Place", "Year"]
df
# Out:
#                                                 Place  Year
# 0                                     Santiago, Chile  2017
# 1                                    El Quisco, Chile  2017
# 2                                 Viña del Mar, Chile  2018
# 3                  San Carlos de Bariloche, Argentina  2018
# 4                               Lago Puelo, Argentina  2018
# 5                            Lago Gutiérrez,Argentina  2018
# 6                        Villa La Angostura,Argentina  2018
# 7                              Villa Traful,Argentina  2018
# 8                              Villa Tacul, Argentina  2018
# 9   Asociación Camping Musical Bariloche, Argentin...  2018
# 10                 San Martín de los Andes, Argentina  2018
# 11                            Lago Flakner, Argentina  2018
# 12                           Colonia Suiza, Argentina  2018
# 13                               El Bolsón, Argentina  2018
# 14                                   Merlo, Argentina  2019
# 15                                Trapiche, Argentina  2019
# 16                                San Luis, Argentina  2020
# 17                               Las Grutas,Argentina  2020
# 18                     Península de Valdez, Argentina  2020
# 19                           Puerto Madryn, Argentina  2020
# 20                       Lago Futalaufquen, Argentina  2020
# 21                           Lago Menendez, Argentina  2020
# 22                          Lago Rivadavia, Argentina  2020
# 23                               El Bolsón, Argentina  2020
# 24                 San Carlos de Bariloche, Argentina  2020
# 25                      Junín de los Andes, Argentina  2020
# 26                        Lago Huechulafken,Argentina  2020
# 27                               Chos Malal,Argentina  2020
# 28                                 Malargüe,Argentina  2020
# 29                                 Neuquén, Argentina  2021
# 30                          Villa Pehuenia, Argentina  2021
# 31                            Lago Aluminé, Argentina  2021
# 32                           Lago Moquehue, Argentina  2021
# 33                          Lago Ñorquinco, Argentina  2021
# 34                      Lago Huechulafquen, Argentina  2021
# 35                             Lago Paimún, Argentina  2021
# 36                             Lago Tromen, Argentina  2021
# 37                 San Martín de los Andes, Argentina  2021
# 38                                La Rioga, Argentina  2021
# 39                               Catamarca, Argentina  2021
# 40                                 Tucumán, Argentina  2021
# 41                                   Salta, Argentina  2021
# 42                                Cafayate, Argentina  2021
# 43                          Tafí del Valle, Argentina  2021
# 44                           Ischigualasto, Argentina  2021
# 45                                San Juan, Argentina  2021

# %%
#geocoding and listing each lat and long for each place

latitude = list()
longitude = list()
for i in df["Place"]:
    g = geocoder.arcgis("{}".format(i))
    lat = g.json['lat']
    lng = g.json['lng']
    latitude.append(lat)
    longitude.append(lng)
print(latitude)
print(longitude)
# Out:
# [-33.43721999999997, -33.39842999999996, -33.023909999999944, -41.141569999999945, -42.06371999999993, -41.20604999999995, -40.76252999999997, -40.65477999999996, -41.044919999999934, -41.06370999999996, -40.153719999999964, -40.47555999999997, -41.093669999999975, -41.956699999999955, -34.66256999999996, -33.094649999999945, -33.30219999999997, -40.802899999999966, -42.49999999999994, -42.77076999999997, -42.85854999999998, -42.696369999999945, -42.604799999999955, -41.956699999999955, -41.141569999999945, -39.941659999999956, -39.76754999999997, -37.373069999999984, -35.476219999999955, -38.951269999999965, -38.87923999999998, -38.918889999999976, -38.89499999999998, -39.13895999999994, -39.76754999999997, -39.713359999999966, -37.09670999999997, -40.153719999999964, -29.413359999999955, -28.487349999999935, -26.948193223999965, -24.78863999999993, -26.073039999999935, -26.85250999999994, -30.082919999999945, -31.533439999999928]
# [-70.65001999999998, -71.69841999999994, -71.55216999999993, -71.29963999999995, -71.59897999999998, -71.41062999999997, -71.64566999999994, -71.39685999999995, -71.57257999999996, -71.52060999999998, -71.35193999999996, -71.49717999999996, -71.50995999999998, -71.53624999999994, -58.72709999999995, -65.99324999999993, -66.33758999999998, -65.08128999999997, -63.99999999999994, -65.04940999999997, -71.60686999999996, -71.80191999999994, -71.66469999999998, -71.53624999999994, -71.29963999999995, -71.07257999999996, -71.33469999999994, -70.27328999999997, -69.58525999999995, -68.06073999999995, -71.18650999999994, -71.13006999999993, -71.26675999999998, -71.28751999999997, -71.33469999999994, -71.57697999999993, -70.10343999999998, -71.35193999999996, -66.85589999999996, -65.78520999999995, -65.36482832199994, -65.41022999999996, -65.97540999999995, -65.70324999999997, -67.94557999999995, -68.51421999999997]

# %%
#adding lat and long to our dataframe

df["Latitude"] = latitude
df["Longitude"] = longitude
df
# Out:
#                                                 Place  Year   Latitude  \
# 0                                     Santiago, Chile  2017 -33.437220
# 1                                    El Quisco, Chile  2017 -33.398430
# 2                                 Viña del Mar, Chile  2018 -33.023910
# 3                  San Carlos de Bariloche, Argentina  2018 -41.141570
# 4                               Lago Puelo, Argentina  2018 -42.063720
# 5                            Lago Gutiérrez,Argentina  2018 -41.206050
# 6                        Villa La Angostura,Argentina  2018 -40.762530
# 7                              Villa Traful,Argentina  2018 -40.654780
# 8                              Villa Tacul, Argentina  2018 -41.044920
# 9   Asociación Camping Musical Bariloche, Argentin...  2018 -41.063710
# 10                 San Martín de los Andes, Argentina  2018 -40.153720
# 11                            Lago Flakner, Argentina  2018 -40.475560
# 12                           Colonia Suiza, Argentina  2018 -41.093670
# 13                               El Bolsón, Argentina  2018 -41.956700
# 14                                   Merlo, Argentina  2019 -34.662570
# 15                                Trapiche, Argentina  2019 -33.094650
# 16                                San Luis, Argentina  2020 -33.302200
# 17                               Las Grutas,Argentina  2020 -40.802900
# 18                     Península de Valdez, Argentina  2020 -42.500000
# 19                           Puerto Madryn, Argentina  2020 -42.770770
# 20                       Lago Futalaufquen, Argentina  2020 -42.858550
# 21                           Lago Menendez, Argentina  2020 -42.696370
# 22                          Lago Rivadavia, Argentina  2020 -42.604800
# 23                               El Bolsón, Argentina  2020 -41.956700
# 24                 San Carlos de Bariloche, Argentina  2020 -41.141570
# 25                      Junín de los Andes, Argentina  2020 -39.941660
# 26                        Lago Huechulafken,Argentina  2020 -39.767550
# 27                               Chos Malal,Argentina  2020 -37.373070
# 28                                 Malargüe,Argentina  2020 -35.476220
# 29                                 Neuquén, Argentina  2021 -38.951270
# 30                          Villa Pehuenia, Argentina  2021 -38.879240
# 31                            Lago Aluminé, Argentina  2021 -38.918890
# 32                           Lago Moquehue, Argentina  2021 -38.895000
# 33                          Lago Ñorquinco, Argentina  2021 -39.138960
# 34                      Lago Huechulafquen, Argentina  2021 -39.767550
# 35                             Lago Paimún, Argentina  2021 -39.713360
# 36                             Lago Tromen, Argentina  2021 -37.096710
# 37                 San Martín de los Andes, Argentina  2021 -40.153720
# 38                                La Rioga, Argentina  2021 -29.413360
# 39                               Catamarca, Argentina  2021 -28.487350
# 40                                 Tucumán, Argentina  2021 -26.948193
# 41                                   Salta, Argentina  2021 -24.788640
# 42                                Cafayate, Argentina  2021 -26.073040
# 43                          Tafí del Valle, Argentina  2021 -26.852510
# 44                           Ischigualasto, Argentina  2021 -30.082920
# 45                                San Juan, Argentina  2021 -31.533440
#
#     Longitude
# 0  -70.650020
# 1  -71.698420
# 2  -71.552170
# 3  -71.299640
# 4  -71.598980
# 5  -71.410630
# 6  -71.645670
# 7  -71.396860
# 8  -71.572580
# 9  -71.520610
# 10 -71.351940
# 11 -71.497180
# 12 -71.509960
# 13 -71.536250
# 14 -58.727100
# 15 -65.993250
# 16 -66.337590
# 17 -65.081290
# 18 -64.000000
# 19 -65.049410
# 20 -71.606870
# 21 -71.801920
# 22 -71.664700
# 23 -71.536250
# 24 -71.299640
# 25 -71.072580
# 26 -71.334700
# 27 -70.273290
# 28 -69.585260
# 29 -68.060740
# 30 -71.186510
# 31 -71.130070
# 32 -71.266760
# 33 -71.287520
# 34 -71.334700
# 35 -71.576980
# 36 -70.103440
# 37 -71.351940
# 38 -66.855900
# 39 -65.785210
# 40 -65.364828
# 41 -65.410230
# 42 -65.975410
# 43 -65.703250
# 44 -67.945580
# 45 -68.514220

# %%
df_copy = df

# %%
#manually correcting the geocoder

df.at[14,"Latitude"] = -32.34751
df.at[14,"Longitude"] = -65.01590
df
# Out:
#                                                 Place  Year   Latitude  \
# 0                                     Santiago, Chile  2017 -33.437220
# 1                                    El Quisco, Chile  2017 -33.398430
# 2                                 Viña del Mar, Chile  2018 -33.023910
# 3                  San Carlos de Bariloche, Argentina  2018 -41.141570
# 4                               Lago Puelo, Argentina  2018 -42.063720
# 5                            Lago Gutiérrez,Argentina  2018 -41.206050
# 6                        Villa La Angostura,Argentina  2018 -40.762530
# 7                              Villa Traful,Argentina  2018 -40.654780
# 8                              Villa Tacul, Argentina  2018 -41.044920
# 9   Asociación Camping Musical Bariloche, Argentin...  2018 -41.063710
# 10                 San Martín de los Andes, Argentina  2018 -40.153720
# 11                            Lago Flakner, Argentina  2018 -40.475560
# 12                           Colonia Suiza, Argentina  2018 -41.093670
# 13                               El Bolsón, Argentina  2018 -41.956700
# 14                                   Merlo, Argentina  2019 -32.347510
# 15                                Trapiche, Argentina  2019 -33.094650
# 16                                San Luis, Argentina  2020 -33.302200
# 17                               Las Grutas,Argentina  2020 -40.802900
# 18                     Península de Valdez, Argentina  2020 -42.500000
# 19                           Puerto Madryn, Argentina  2020 -42.770770
# 20                       Lago Futalaufquen, Argentina  2020 -42.858550
# 21                           Lago Menendez, Argentina  2020 -42.696370
# 22                          Lago Rivadavia, Argentina  2020 -42.604800
# 23                               El Bolsón, Argentina  2020 -41.956700
# 24                 San Carlos de Bariloche, Argentina  2020 -41.141570
# 25                      Junín de los Andes, Argentina  2020 -39.941660
# 26                        Lago Huechulafken,Argentina  2020 -39.767550
# 27                               Chos Malal,Argentina  2020 -37.373070
# 28                                 Malargüe,Argentina  2020 -35.476220
# 29                                 Neuquén, Argentina  2021 -38.951270
# 30                          Villa Pehuenia, Argentina  2021 -38.879240
# 31                            Lago Aluminé, Argentina  2021 -38.918890
# 32                           Lago Moquehue, Argentina  2021 -38.895000
# 33                          Lago Ñorquinco, Argentina  2021 -39.138960
# 34                      Lago Huechulafquen, Argentina  2021 -39.767550
# 35                             Lago Paimún, Argentina  2021 -39.713360
# 36                             Lago Tromen, Argentina  2021 -37.096710
# 37                 San Martín de los Andes, Argentina  2021 -40.153720
# 38                                La Rioga, Argentina  2021 -29.413360
# 39                               Catamarca, Argentina  2021 -28.487350
# 40                                 Tucumán, Argentina  2021 -26.948193
# 41                                   Salta, Argentina  2021 -24.788640
# 42                                Cafayate, Argentina  2021 -26.073040
# 43                          Tafí del Valle, Argentina  2021 -26.852510
# 44                           Ischigualasto, Argentina  2021 -30.082920
# 45                                San Juan, Argentina  2021 -31.533440
#
#     Longitude
# 0  -70.650020
# 1  -71.698420
# 2  -71.552170
# 3  -71.299640
# 4  -71.598980
# 5  -71.410630
# 6  -71.645670
# 7  -71.396860
# 8  -71.572580
# 9  -71.520610
# 10 -71.351940
# 11 -71.497180
# 12 -71.509960
# 13 -71.536250
# 14 -65.015900
# 15 -65.993250
# 16 -66.337590
# 17 -65.081290
# 18 -64.000000
# 19 -65.049410
# 20 -71.606870
# 21 -71.801920
# 22 -71.664700
# 23 -71.536250
# 24 -71.299640
# 25 -71.072580
# 26 -71.334700
# 27 -70.273290
# 28 -69.585260
# 29 -68.060740
# 30 -71.186510
# 31 -71.130070
# 32 -71.266760
# 33 -71.287520
# 34 -71.334700
# 35 -71.576980
# 36 -70.103440
# 37 -71.351940
# 38 -66.855900
# 39 -65.785210
# 40 -65.364828
# 41 -65.410230
# 42 -65.975410
# 43 -65.703250
# 44 -67.945580
# 45 -68.514220

# %%
# creating the map

arg = geocoder.arcgis("Argentina")
m = folium.Map(location = (arg.lat, arg.lng), zoom_start = 4.5)
for lat, lng, label, year in zip(df['Latitude'], df['Longitude'], df['Place'], df["Year"]):
    label = folium.Popup(label + ' '+str(year), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3572a38ac00bfa7f584da9df4f8f9fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3572a38ac00bfa7f584da9df4f8f9fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a3572a38ac00bfa7f584da9df4f8f9fd = L.map(
#                 &quot;map_a3572a38ac00bfa7f584da9df4f8f9fd&quot;,
#                 {
#                     center: [-35.49575818399995, -65.07154210799996],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c555523d286a9356c750bae49e1540d6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a3572a38ac00bfa7f584da9df4f8f9fd);
#
#
#             var circle_marker_313d4b625486b9334b14185842a5b3f6 = L.circleMarker(
#                 [-33.43721999999997, -70.65001999999998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a3572a38ac00bfa7f584da9df4f8f9fd);
#
#
#         var popup_89ebedefb47d62dedfd0aec773980268 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a57896d69e01666bdcf15dc3bd9e519f = $(`&lt;div id=&quot;html_a57896d69e01666bdcf15dc3bd9e519f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santiago, Chile 2017&lt;/div&gt;`)[0];
#             popup_89ebedefb47d62dedfd0aec773980268.setContent(html_a57896d69e01666bdcf15dc3bd9e519f);
#
#
#         circle_marker_313d4b625486b9334b14185842a5b3f6.bindPopup(popup_89ebedefb47d62dedfd0aec773980268)
#         ;
#
#
#
#
#             var circle_marker_07a5d96e9793e440d96a3a23e35b6290 = L.circleMarker(
#                 [-33.39842999999996, -71.69841999999994],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a3572a38ac00bfa7f584da9df4f8f9fd);
#
#
#         var popup_7a05ba30b59e19e1a16fc6bd9da49a4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1984cb0531267326ae27916f6128f2f7 = $(`&lt;div id=&quot;html_1984cb0531267326ae27916f6128f2f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El Quisco, Chile 2017&lt;/div&gt;`)[0];
#             popup_7a05ba30b59e19e1a16fc6bd9da49a4e.setContent(html_1984cb0531267326ae27916f6128f2f7);
#
#
#         circle_marker_07a5d96e9793e440d96a3a23e35b6290.bindPopup(popup_7a05ba30b59e19e1a16fc6bd9da49a4e)
#         ;
#
#
#
#
#             var circle_marker_0ea94dd38b6ea82cb47843c3d53fab35 = L.circleMarker(
#                 [-33.023909999999944, -71.55216999999993],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a3572a38ac00bfa7f584da9df4f8f9fd);
#
#
#         var popup_4d968218a0ab544f23446787f9751919 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_17684d6b9aefc37c03a13a788d5ef764 = $(`&lt;div id=&quot;html_17684d6b9aefc37c03a13a788d5ef764&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Viña del Mar, Chile 2018&lt;/div&gt;`)[0];
#             popup_4d968218a0ab544f23446787f9751919.setContent(html_17684d6b9aefc37c03a13a788d5ef764);
#
#
#         circle_marker_0ea94dd38b6ea82cb47843c3d53fab35.bindPopup(popup_4d968218a0ab544f23446787f9751919)
#         ;
#
#
#
#
#             var circle_marker_653ba92330be3e0f6f517ca820fb0df3 = L.circleMarker(
#                 [-41.141569999999945, -71.29963999999995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quo

# %%
#creating the map with the colors

arg = geocoder.arcgis("Argentina")
m = folium.Map(location = (arg.lat, arg.lng), zoom_start = 4.5)

years = pd.unique(df["Year"])
x = np.arange(len(years))
ys = [i + x + (i*x)**2 for i in range(len(years))]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

for lat, lng, label, year, in zip(df['Latitude'], df['Longitude'], df['Place'], df["Year"]):
    label = folium.Popup(label + ' '+str(year), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[year-2017],
        fill=True,
        fill_color=rainbow[year-2017],
        fill_opacity=0.7,
        parse_html=False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6761acd38317a6619b317010979c34f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6761acd38317a6619b317010979c34f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6761acd38317a6619b317010979c34f9 = L.map(
#                 &quot;map_6761acd38317a6619b317010979c34f9&quot;,
#                 {
#                     center: [-35.49575818399995, -65.07154210799996],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bce41d4dfb66cc2b77543419f3149d47 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6761acd38317a6619b317010979c34f9);
#
#
#             var circle_marker_3e3e67e3dd690c781c527093f31a0aec = L.circleMarker(
#                 [-33.43721999999997, -70.65001999999998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8000ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6761acd38317a6619b317010979c34f9);
#
#
#         var popup_200993934571958594f60c694c50cbe3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c92a0ac94ed1f02e015cbd1dc4d19d91 = $(`&lt;div id=&quot;html_c92a0ac94ed1f02e015cbd1dc4d19d91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santiago, Chile 2017&lt;/div&gt;`)[0];
#             popup_200993934571958594f60c694c50cbe3.setContent(html_c92a0ac94ed1f02e015cbd1dc4d19d91);
#
#
#         circle_marker_3e3e67e3dd690c781c527093f31a0aec.bindPopup(popup_200993934571958594f60c694c50cbe3)
#         ;
#
#
#
#
#             var circle_marker_0b5500efaa42d3c86c9d2c23ba20a1be = L.circleMarker(
#                 [-33.39842999999996, -71.69841999999994],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8000ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6761acd38317a6619b317010979c34f9);
#
#
#         var popup_8931beb62aecf9220cc393f3b17eb36f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4f5ae847378b4529a5fcfa9680c2e05f = $(`&lt;div id=&quot;html_4f5ae847378b4529a5fcfa9680c2e05f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El Quisco, Chile 2017&lt;/div&gt;`)[0];
#             popup_8931beb62aecf9220cc393f3b17eb36f.setContent(html_4f5ae847378b4529a5fcfa9680c2e05f);
#
#
#         circle_marker_0b5500efaa42d3c86c9d2c23ba20a1be.bindPopup(popup_8931beb62aecf9220cc393f3b17eb36f)
#         ;
#
#
#
#
#             var circle_marker_ae6d4b231dcb8c5d7fedc10bd2450329 = L.circleMarker(
#                 [-33.023909999999944, -71.55216999999993],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00b5eb&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00b5eb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6761acd38317a6619b317010979c34f9);
#
#
#         var popup_11959bd74d9cbd0bb13a48ae7c798788 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ab22b60d8f1bd099cad3d2fe70a83ddd = $(`&lt;div id=&quot;html_ab22b60d8f1bd099cad3d2fe70a83ddd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Viña del Mar, Chile 2018&lt;/div&gt;`)[0];
#             popup_11959bd74d9cbd0bb13a48ae7c798788.setContent(html_ab22b60d8f1bd099cad3d2fe70a83ddd);
#
#
#         circle_marker_ae6d4b231dcb8c5d7fedc10bd2450329.bindPopup(popup_11959bd74d9cbd0bb13a48ae7c798788)
#         ;
#
#
#
#
#             var circle_marker_d4654cd308ff75e991a007f800007bdf = L.circleMarker(
#                 [-41.141569999999945, -71.29963999999995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00b5eb&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00b5eb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot

# %% [markdown]
# ###### Map showing the places grouped by colors was made.
